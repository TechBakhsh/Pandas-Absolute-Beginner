# %%
# import library
import pandas as pd

# %% [markdown]
# # Load Data

# %%
df=pd.read_csv("New_sales.csv")

# %%
df.head(10)
# Out:
#    Unnamed: 0       State  Total_Expenses  Sales  Profit Market  Trade  \
# 0           0  California            63.0  109.0  -131.0   West     40
# 1           1  California            55.0  201.0    88.0   West     24
# 2           2  California           700.0  289.0    25.0   West    109
# 3           3  California           113.0  576.0   216.0   West     81
# 4           4  California            37.0  247.0   148.0   West     26
# 5           5  California            99.0  582.0   291.0   West     77
# 6           6  California            25.0   90.0    26.0   West     12
# 7           7  California            43.0  276.0   120.0   West     31
# 8           8  California            32.0  187.0    79.0   West     21
# 9           9  California           142.0  687.0   364.0   West     90
#
#   Product_Type  Inventory     Type  New_Column
# 0       Coffee     2947.0  Regular       172.0
# 1          Tea      659.0  Regular       256.0
# ...

# %%
df.tail()
# Out:
#       Unnamed: 0      State  Total_Expenses  Sales  Profit   Market  Trade  \
# 4224        4236  Wisconsin            34.0   90.0    20.0  Central     11
# 4225        4237  Wisconsin            36.0  113.0    31.0  Central     14
# 4226        4238  Wisconsin            86.0  150.0     1.0  Central     57
# 4227        4239  Wisconsin            79.0  131.0    -3.0  Central     49
# 4228        4240  Wisconsin            87.0  165.0     4.0  Central     58
#
#      Product_Type  Inventory     Type  New_Column
# 4224          Tea      458.0  Regular       124.0
# 4225          Tea      454.0  Regular       149.0
# 4226          Tea      506.0  Regular       236.0
# 4227          Tea      627.0  Regular       210.0
# 4228          Tea      513.0  Regular       252.0

# %%
df.shape
# Out:
# (4229, 11)

# %% [markdown]
# # Panda DataFrame

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4229 entries, 0 to 4228
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      4229 non-null   int64
#  1   State           4229 non-null   object
#  2   Total_Expenses  4229 non-null   float64
#  3   Sales           4229 non-null   float64
#  4   Profit          4229 non-null   float64
#  5   Market          4229 non-null   object
#  6   Trade           4229 non-null   int64
#  7   Product_Type    4229 non-null   object
#  8   Inventory       4229 non-null   float64
#  9   Type            4229 non-null   object
#  10  New_Column      4229 non-null   float64
# dtypes: float64(5), int64(2), object(4)
# memory usage: 363.6+ KB

# %%
df.describe()
# Out:
#         Unnamed: 0  Total_Expenses        Sales       Profit        Trade  \
# count  4229.000000     4229.000000  4229.000000  4229.000000  4229.000000
# mean   2125.081343       54.102152   192.298416    60.765666    31.104280
# std    1222.373708       33.746537   150.330235   101.348158    26.986835
# min       0.000000       10.000000    17.000000  -638.000000     0.000000
# 25%    1069.000000       33.000000   100.000000    17.000000    13.000000
# 50%    2126.000000       46.000000   137.000000    40.000000    22.000000
# 75%    3183.000000       65.000000   230.000000    91.000000    39.000000
# max    4240.000000      700.000000   912.000000   778.000000   156.000000
#
#          Inventory   New_Column
# count  4229.000000  4229.000000
# mean    747.253724   246.400568
# std     660.544773   174.436784
# min   -3534.000000    38.000000
# 25%     430.000000   138.000000
# 50%     619.000000   190.000000
# 75%     898.000000   285.000000
# max    8252.000000  1090.000000

# %%
insects=['Ants', 'Cricket','Bee']

# %%
type(insects)
# Out:
# list

# %%
#Creating a DataFrame named Data_insects
Data_insects = pd.DataFrame(insects, columns=['insects'])
Data_insects
# Out:
#    insects
# 0     Ants
# 1  Cricket
# 2      Bee

# %%
animals={'Mammas':['Lion','Cow','Sheep'],
         'insects':['Ants','Bee','Cricket']}

# %%
data_animals = pd.DataFrame(animals)
data_animals
# Out:
#   Mammas  insects
# 0   Lion     Ants
# 1    Cow      Bee
# 2  Sheep  Cricket

# %%
data_animals['Mammas']
# Out:
# 0     Lion
# 1      Cow
# 2    Sheep
# Name: Mammas, dtype: object

# %%
data_animals.iloc[0]
# Out:
# Mammas     Lion
# insects    Ants
# Name: 0, dtype: object

# %% [markdown]
# # Filtering Data

# %%
highest_sales=(df['Sales']>300)
highest_sales
# Out:
# 0       False
# 1       False
# 2       False
# 3        True
# 4       False
#         ...
# 4224    False
# 4225    False
# 4226    False
# 4227    False
# 4228    False
# Name: Sales, Length: 4229, dtype: bool

# %%
df.loc[highest_sales]
# Out:
#       Unnamed: 0       State  Total_Expenses  Sales  Profit   Market  Trade  \
# 3              3  California           113.0  576.0   216.0     West     81
# 5              5  California            99.0  582.0   291.0     West     77
# 9              9  California           142.0  687.0   364.0     West     90
# 10            10  California           166.0  902.0   508.0     West    127
# 11            11  California           139.0  664.0   349.0     West     87
# ...          ...         ...             ...    ...     ...      ...    ...
# 3920        3932  Washington            71.0  329.0   171.0     West     40
# 3921        3933  Washington            73.0  334.0   171.0     West     41
# 3992        4004  Washington            75.0  347.0   179.0     West     40
# 4110        4122   Wisconsin           149.0  317.0    35.0  Central    120
# 4201        4213   Wisconsin           139.0  314.0    48.0  Central    120
#
#      Product_Type  Inventory     Type  New_Column
# ...

# %%
df['Profit'].unique()
# Out:
# array([-131.,   88.,   25.,  216.,  148.,  291.,   26.,  120.,   79.,
#         364.,  508.,  349.,   47.,  203.,  220.,  292.,   84.,  165.,
#         174.,   52.,  128.,  230., -182.,   59.,  317.,  160.,   38.,
#          92.,  111.,  134.,  199.,  105.,  221.,  232.,   27.,   40.,
#         313.,  245.,   43.,  218., -180.,   62.,  106.,  150.,   67.,
#         101., -142.,   54.,   48.,   30.,   39.,  326.,  334.,  157.,
#         188.,  240.,  265.,   98.,   83.,   70.,  102.,  258.,  135.,
#         228.,  493., -189.,   86.,   58.,   50.,   31.,   46.,  249.,
#          68.,  153.,   89.,  262.,  243.,  253.,  129., -139., -113.,
#         465.,   56.,   45.,  357.,  156.,  186.,   69.,  112.,  146.,
#         123.,  149.,  -56.,   71.,  192.,   94.,  155.,   53.,  211.,
#         -40.,  247., -137., -188.,  117., -156.,  295.,  368.,  511.,
#        -117., -121., -174.,   41.,  259.,  159.,  205.,  104.,  125.,
# ...

# %% [markdown]
# # Update Rows And Columns

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'State', 'Total_Expenses', 'Sales', 'Profit', 'Market',
#        'Trade', 'Product_Type', 'Inventory', 'Type', 'New_Column'],
#       dtype='object')

# %%
df.Profit
# Out:
# 0      -131.0
# 1        88.0
# 2        25.0
# 3       216.0
# 4       148.0
#         ...
# 4224     20.0
# 4225     31.0
# 4226      1.0
# 4227     -3.0
# 4228      4.0
# Name: Profit, Length: 4229, dtype: float64

# %%
# Adding a name to the DataFrame
data_animals.name = 'my_animals_data'

# Display the updated DataFrame
print(data_animals)
# Out:
#   Mammas  insects
# 0   Lion     Ants
# 1    Cow      Bee
# 2  Sheep  Cricket

# %%
# Renaming columns
data_animals = data_animals.rename(columns={'original_name': 'new_name'})

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'State', 'Total_Expenses', 'Sales', 'Profit', 'Market',
#        'Trade', 'Product_Type', 'Inventory', 'Type', 'New_Column'],
#       dtype='object')

# %%
df.sort_values(by='Sales')
# Out:
#       Unnamed: 0       State  Total_Expenses  Sales  Profit Market  Trade  \
# 1902        1914      Nevada           126.0   17.0  -354.0   West     93
# 1911        1923      Nevada           124.0   18.0  -524.0   West    100
# 1905        1917      Nevada           133.0   18.0  -380.0   West    100
# 2022        2034      Nevada           147.0   19.0  -430.0   West    114
# 2024        2036      Nevada           132.0   19.0  -552.0   West     93
# ...          ...         ...             ...    ...     ...    ...    ...
# 2600        2612    New York           166.0  904.0   511.0   East    127
# 128          131  California           178.0  910.0   368.0   West    127
# 2633        2645    New York           178.0  910.0   368.0   East    127
# 153          157  California           178.0  912.0   370.0   West    127
# 2632        2644    New York           178.0  912.0   370.0   East    127
#
#      Product_Type  Inventory     Type  New_Column
# ...

# %%
df.sort_values(by=['Sales', 'Profit'],ascending=False)
# Out:
#       Unnamed: 0       State  Total_Expenses  Sales  Profit Market  Trade  \
# 153          157  California           178.0  912.0   370.0   West    127
# 2632        2644    New York           178.0  912.0   370.0   East    127
# 128          131  California           178.0  910.0   368.0   West    127
# 2633        2645    New York           178.0  910.0   368.0   East    127
# 129          132  California           166.0  904.0   511.0   West    127
# ...          ...         ...             ...    ...     ...    ...    ...
# 2022        2034      Nevada           147.0   19.0  -430.0   West    114
# 2024        2036      Nevada           132.0   19.0  -552.0   West     93
# 1905        1917      Nevada           133.0   18.0  -380.0   West    100
# 1911        1923      Nevada           124.0   18.0  -524.0   West    100
# 1902        1914      Nevada           126.0   17.0  -354.0   West     93
#
#      Product_Type  Inventory     Type  New_Column
# ...

# %%
df.sort_index(ascending=False)
# Out:
#       Unnamed: 0       State  Total_Expenses  Sales  Profit   Market  Trade  \
# 4228        4240   Wisconsin            87.0  165.0     4.0  Central     58
# 4227        4239   Wisconsin            79.0  131.0    -3.0  Central     49
# 4226        4238   Wisconsin            86.0  150.0     1.0  Central     57
# 4225        4237   Wisconsin            36.0  113.0    31.0  Central     14
# 4224        4236   Wisconsin            34.0   90.0    20.0  Central     11
# ...          ...         ...             ...    ...     ...      ...    ...
# 4              4  California            37.0  247.0   148.0     West     26
# 3              3  California           113.0  576.0   216.0     West     81
# 2              2  California           700.0  289.0    25.0     West    109
# 1              1  California            55.0  201.0    88.0     West     24
# 0              0  California            63.0  109.0  -131.0     West     40
#
#      Product_Type  Inventory     Type  New_Column
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0        0
# State             0
# Total_Expenses    0
# Sales             0
# Profit            0
# Market            0
# Trade             0
# Product_Type      0
# Inventory         0
# Type              0
# New_Column        0
# dtype: int64
